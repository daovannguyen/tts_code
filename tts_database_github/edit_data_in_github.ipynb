# %%
#@title Default title text
import os
import shutil
import json
from tqdm import tqdm

# %%
import os
import shutil
for i in os.listdir('/content/'):
  if i.find('drive') == -1 :
    try:
      shutil.rmtree(os.path.join('/content/', i))
    except:
      os.remove(os.path.join('/content/', i))

# %%
# !git clone https://github.com/daovannguyen/tts.git
# %cd tts
# Out:
# Cloning into 'tts'...
# remote: Enumerating objects: 3973, done.
# remote: Counting objects: 100% (3973/3973), done.
# remote: Compressing objects: 100% (3944/3944), done.
# remote: Total 3973 (delta 31), reused 3961 (delta 23), pack-reused 0
# Receiving objects: 100% (3973/3973), 72.27 MiB | 18.25 MiB/s, done.
# Resolving deltas: 100% (31/31), done.
# /content/tts

# %%
with open('/content/tts/json/csdl.json', 'r') as f:
  csdl = json.load(f)
x = csdl[20:]
x.sort()
with open('/content/tts/json/csdl.json', 'w') as f:
  json.dump(x, f)
print("Con: ", len(x))

print(x)
# Out:
# Con:  0
# []

# %%
'''
a = []
for i in os.listdir('/content/drive/MyDrive'):
  if i.find('.mp3') > -1:
    a.append(i[:-4] + '.txt')
print(a)
'''
# Out:
# "\na = []\nfor i in os.listdir('/content/drive/MyDrive'):\n  if i.find('.mp3') > -1:\n    a.append(i[:-4] + '.txt')\nprint(a)\n"

# %%
'''
x = []
for i in os.listdir('/content/tts/text'):
  dem = 0
  for j in a:
    if i == j:
      dem = dem + 1
  if dem == 0:
    x.append(i)
x.sort()
print(x)
'''
# Out:
# "\nx = []\nfor i in os.listdir('/content/tts/text'):\n  dem = 0\n  for j in a:\n    if i == j:\n      dem = dem + 1\n  if dem == 0:\n    x.append(i)\nx.sort()\nprint(x)\n"

# %%
'''
x.remove('0001_8.txt')
x.remove('0001_5.txt')
x = ['0001_5.txt', '0001_8.txt'] + x
'''
# Out:
# "\nx.remove('0001_8.txt')\nx.remove('0001_5.txt')\nx = ['0001_5.txt', '0001_8.txt'] + x\n"

# %%
'''
with open('/content/tts/json/csdl.json', 'w') as f:
  json.dump(x, f)
'''
# Out:
# "\nwith open('/content/tts/json/csdl.json', 'w') as f:\n  json.dump(x, f)\n"

# %%
# !git config --global user.email "vannguyen86068000@gmail.com"
# !git config --global user.name "daovannguyen"
# !git add *
# !git commit -m "hfhfhfhf"
# !git remote rm origin
# !git remote add origin https://daovannguyen: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@github.com/daovannguyen/tts.git
! git push origin main
# Out:
# [main fc73cd8] hfhfhfhf
#  1 file changed, 1 insertion(+), 1 deletion(-)
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (4/4), 342 bytes | 342.00 KiB/s, done.
# Total 4 (delta 0), reused 0 (delta 0)
# To https://github.com/daovannguyen/tts.git
#    77d2f28..fc73cd8  main -> main

# %%
# %cd /content/
# Out:
# /content
