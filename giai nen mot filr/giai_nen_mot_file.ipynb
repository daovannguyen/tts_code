# %%
import os
import shutil

# %%
name = '0002'

# %%
'''
path = ''
infor = []
for folder in os.listdir('/content/drive/MyDrive/other gmails'):
  for root, dir, files in os.walk(os.path.join('/content/drive/MyDrive/other gmails', folder, 'zip')):
    for i in files:
      if i.find('.zip') > -1:
        infor.append([i, os.path.join(root, i)])
print(infor)
import json
with open('/content/drive/MyDrive/tts/giai nen mot filr/sach_path.json', 'w') as f:
  json.dump(infor, f)

'''

# %%
path = ''
infor = []
for folder in os.listdir('/content/drive/MyDrive/other gmails'):
  for root, dir, files in os.walk(os.path.join('/content/drive/MyDrive/other gmails', folder, 'zip')):
    for i in files:
      if i.find('.zip') > -1:
        infor.append([i, os.path.join(root, i)])
print(infor)
import json
with open('/content/drive/MyDrive/tts/giai nen mot filr/sach_path.json', 'w') as f:
  json.dump(infor, f)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import json
path = ''
with open('/content/drive/MyDrive/tts/giai nen mot filr/sach_path.json', 'r') as f:
  x = json.load(f)
for i in x:
  if i[0] == name + '.zip':
    path = i[1]
    break
print(path)

# %%
shutil.rmtree('/content/drive/MyDrive/tts/giai nen mot filr/a')
os.mkdir('/content/drive/MyDrive/tts/giai nen mot filr/a')

# %%
import zipfile
with zipfile.ZipFile(path, 'r') as zip_ref:
    zip_ref.extractall('/content/drive/MyDrive/tts/giai nen mot filr/a')
